# %%
from IPython.display import display,HTML,Markdown,Image,YouTubeVideo
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import pyglet
from ipywidgets import interact
from ipywidgets import interact_manual

# %%
from IPython.display import Image
p1=Image(filename='./e1.jpg')
p2=Image(filename='./e2.png')
p3=Image(filename='./e3.jpg')
p4=Image(filename='./e4.jpg')
p5=Image(filename='./e5.jpg')
p6=Image(filename='./e6.jpg')
p7=Image(filename='./e7.png')
p8=Image(filename='./e8.jpg')
p9=Image(filename='./e9.jpg')
p10=Image(filename='./e10.jpg')
p11=Image(filename='./e11.png')
p12=Image(filename='./e12.jpg')



egg="今天是什麼心情呢^・ω・^ "
print(f"{egg:^42s}")
def f(x):
    return(x)
def h(x):
    a=f(x)
    if (a=="sorrowful"):
        display(p1)
        display(YouTubeVideo("jCVNCHjh92c"))
        
    if (a=="happy"):
        display(p2)
        display(YouTubeVideo("fLexgOxsZu0"))
        
    if (a=="excited"):
        display(p3)
        display(YouTubeVideo("kJQP7kiw5Fk"))
        
    if (a=="partytime"):
        display(p4)
        display(YouTubeVideo("t4H_Zoh7G5A"))
        
    if (a=="mad"):
        display(p5)
        display(YouTubeVideo("6Ejga4kJUts"))
        
    if (a=="monday_blue"):
        display(p6)
        display(YouTubeVideo("jZhQOvvV45w"))
        
    if (a=="nervous"):
        display(p7)
        display(YouTubeVideo("x_Faj7UIEcI"))
        
    if (a=="having a difficult time"):
        display(p8)
        display(YouTubeVideo("wEJd2RyGm8Q"))
        
    if (a=="brokenhearted"):
        display(p11)
        display(YouTubeVideo("jD9dr2ZRm9A"))
        
    if (a=="spending time alone"):
        display(p9) 
        display(YouTubeVideo("c-3vPxKdj6o"))
        
    if (a=="in_the_cafe"):
        display(p12)
        display(YouTubeVideo("aoIHbVlM8TY"))
        
    if (a=="fall_in_love"):
        display(p10)
        display(YouTubeVideo("2Vv-BfVoq4g"))
        
    
    
interact(h,x=["choose","sorrowful","happy","monday_blue","excited","partytime","mad","nervous","having a difficult time","brokenhearted","spending time alone","in_the_cafe","fall_in_love"])
# Out:
#               今天是什麼心情呢^・ω・^
# interactive(children=(Dropdown(description='x', options=('choose', 'sorrowful', 'happy', 'monday_blue', 'excit…
# <function __main__.h(x)>

# %%
import csv
with open('Mt8 -1.csv', newline='') as csvfile:
    t=pd.read_csv(csvfile)
    
t=pd.DataFrame(t)
t


t=t.drop(index=[0, 1,2,3,53])
t.head()
# Out:
#       表8　歷 年 平 均 氣 溫 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4    民國前 十 五 年(1897)      21.7           .          .          .          .
# 5        十 四 年(1898)      21.8           .          .          .          .
# 6        十 三 年(1899)      21.4           .          .          .          .
# 7        十 二 年(1900)      21.6           .          .          .          .
# 8        十 一 年(1901)      21.1           .          .          .          .
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 4          .      22.4       24.0           .  ...           .           .
# 5          .      22.2       23.2           .  ...           .           .
# 6          .      21.8       22.7           .  ...           .           .
# 7          .      22.3       23.1           .  ...           .           .
# 8          .      22.0       22.8           .  ...       22.8            .
#
# ...

# %%
t=t.reindex(columns=['Unnamed: 1'])
t

t= t.applymap(float)
t.head()
# Out:
#    Unnamed: 1
# 4        21.7
# 5        21.8
# 6        21.4
# 7        21.6
# 8        21.1

# %%
t.columns.values
t.columns = ['taipei']
year=list(range(1897,1946))
t.index=year
t.head()
# Out:
#       taipei
# 1897    21.7
# 1898    21.8
# 1899    21.4
# 1900    21.6
# 1901    21.1

# %%
t.plot(use_index=True,title='The average temperature(1897-1945)',grid=True)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource
t.index.name = 'index'

source = ColumnDataSource(data = t)

# %%
t.index.name = 'a'                      
source = ColumnDataSource(data = t)
p = figure(plot_width=600, plot_height=400)
p.line(x='a',y='taipei',source = source,     
       line_width=1, line_alpha = 0.8, line_color = 'orange',line_dash = [10,4]) 


show(p)
