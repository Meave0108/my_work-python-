# %%
a="aa"
print("≧ω≦:Hi!想跟我聊什麼呢?")

while(a!=" "):
    a=input(">> ")
    if ('難過'in a or'傷心' in a or'不順' in a):
        print("O.O :拍拍，怎麼了?")
    elif('幫' in a):
        print("o^ ^o :當然")
    elif('吃飯' in a):
        print("ˇヘˇ :抱歉，愛莫能助")
    elif('朋友' in a):
        print("ˇヘˇ:那是你的問題")
    elif(a=='......'):
        break
    else:
        print("◣_◢:沒錢就吃土ㄚ，關我屁事?")

# %% [markdown]
# ## 記得小時候考試分數出來，總免不了家長親友問起(怕...)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from IPython.display import Image

# %%
b="bb"
while(b!=" "):
    Q=input('孩子，你考多少分ㄚ?')
    Q=float(Q)
    
    if 10<Q<60:
        print("家長反應:")
        Image(filename='./b.png')
    elif Q<10: 
        break
# Out:
# 孩子，你考多少分ㄚ?40
# 家長反應:
# 孩子，你考多少分ㄚ?9

# %%
from IPython.display import Image, display

listOfImageNames = ['./d.png',
                    './b.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))

# %%
if 10<Q<60:
        print("家長反應:")
        print (Image(filename='./g.png') )
elif Q==100:
        print("家長反應:")
        print (Image(filename='./d.png') )
elif Q<10: 
        break     
else:
        print("家長反應:")
        print (Image(filename='./k.png') )
# Out:
#   File "<ipython-input-11-2cfefc6dc839>", line 11
#     print (Image(filename='./k.png') )
#            ^
# SyntaxError: 'break' outside loop
