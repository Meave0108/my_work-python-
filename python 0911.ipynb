# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-np.sqrt(107204002),np.sqrt(5),100)

# %%
y=2*np.tan(x)

# %%
a=plt.subplot(facecolor = 'black')
a=plt.plot(x,y,'white',linestyle='--',marker='*')
